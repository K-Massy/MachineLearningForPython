# %% [markdown]
# # matplotlibの結果をインライン表示する
#
# 以下の宣言を実行します。

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import numpy as np
x = np.arange(-20, 20, 0.1)
y = np.sin(x)
plt.plot(x, y)
